# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(0.,10.,100)
y = np.polyval([1,2,-3],x) + np.random.normal(0,10,100)

# %%
plt.scatter(x,y)

# %%
def line(x, m, b):
    return m * x + b

# %%
popt,pcov = curve_fit(line, x, y)

# %%
plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

# %%
plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
yfit = line(xfit, *popt)

plt.plot(xfit, yfit)

# %%
plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
mfit, bfit = popt
yfit = line(xfit, mfit, bfit)

plt.plot(xfit, yfit)

# %%
def quadretic(x, a, b, c):
    return a * x**2 + b * x + c

popt,pcov = curve_fit(quadretic, x, y)

plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
afit, bfit, cfit =  popt
yfit = quadretic(xfit, afit, bfit, cfit)

plt.plot(xfit, yfit)

popt,pcov = curve_fit(line, x, y)

yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

# %%
def quadretic(x, a, b, c):
    return a * x**2 + b * x + c

def toomuch(x, a, b, c, d, e, f):
    return a * x**5 + b * x**4 + c * x**3 + d * x**2 + e * x + f

def homework(x, a, b, c, d):
    return a *x**3 + b * x**2 + c * x + d

popt,pcov = curve_fit(quadretic, x, y)

plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
afit, bfit, cfit =  popt
yfit = quadretic(xfit, afit, bfit, cfit)

plt.plot(xfit, yfit)

popt,pcov = curve_fit(line, x, y)

yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

popt,pcov = curve_fit(toomuch, x, y)

afit, bfit, cfit, dfit, efit, ffit = popt

yfit = toomuch(xfit, *popt)
plt.plot(xfit, yfit)

popt,pcov = curve_fit(homework, x, y)

afit, bfit, cfit, dfit = popt

yfit = homework(xfit, *popt)
plt.plot(xfit, yfit)

# %%
def evenmore(x, a, b, c, d, e, f):
    return a * x + b * x**2 + c * x**3 + d * x**4 + e * x**5 + f

def quadretic(x, a, b, c):
    return a * x**2 + b * x + c

def toomuch(x, a, b, c, d, e, f):
    return a * x**5 + b * x**4 + c * x**3 + d * x**2 + e * x + f

popt,pcov = curve_fit(quadretic, x, y)

plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
afit, bfit, cfit =  popt
yfit = quadretic(xfit, afit, bfit, cfit)

plt.plot(xfit, yfit)

popt,pcov = curve_fit(line, x, y)

yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

popt,pcov = curve_fit(toomuch, x, y)

afit, bfit, cfit, dfit, efit, ffit = popt

yfit = toomuch(xfit, *popt)
plt.plot(xfit, yfit)
    
popt, pcov = curve_fit(evenmore, x, y)
afit, bfit, cfit, dfit, efit, ffit = popt
yfit = evenmore(xfit, *popt)

plt.plot(xfit, yfit, color = 'red')

# %%
def trig(x, a, b, c, d):
    return a * np.sin(b - x) + c * x**2 + d

def evenmore(x, a, b, c, d, e, f):
    return a * x + b * x**2 + c * x**3 + d * x**4 + e * x**5 + f

def quadretic(x, a, b, c):
    return a * x**2 + b * x + c

def toomuch(x, a, b, c, d, e, f):
    return a * x**5 + b * x**4 + c * x**3 + d * x**2 + e * x + f

popt,pcov = curve_fit(quadretic, x, y)

plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
afit, bfit, cfit =  popt
yfit = quadretic(xfit, afit, bfit, cfit)

plt.plot(xfit, yfit)

popt,pcov = curve_fit(line, x, y)

yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

popt,pcov = curve_fit(toomuch, x, y)

afit, bfit, cfit, dfit, efit, ffit = popt

yfit = toomuch(xfit, *popt)
plt.plot(xfit, yfit)
    
popt, pcov = curve_fit(evenmore, x, y)
afit, bfit, cfit, dfit, efit, ffit = popt
yfit = evenmore(xfit, *popt)

plt.plot(xfit, yfit, color = 'red')
   
popt, pcov = curve_fit(trig, x, y)
afit, bfit, cfit, dfit = popt
yfit = trig(xfit, *popt)

plt.plot(xfit, yfit)

# %%
#Jade S
import math
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt


def sin(x,a,b,c):
    return a * np.sin(b * x) + c


popt,pcov = curve_fit(sin, x, y)

plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
afit,bfit,cfit =  popt
yfit = sin(xfit, bfit, afit,cfit)

plt.plot(xfit, yfit)

#popt,pcov = curve_fit(line, x, y)

#yfit = sin(xfit, cfit, popt[0], popt[1])

#plt.plot(xfit, yfit)

# %%
## I added another curve to the work I did in last week's class as homework.
