# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(0.,10.,100)
y = np.polyval([1,2,-3],x) + np.random.normal(0,10,100)

# %%
plt.scatter(x,y)

# %%
def line(x, m, b):
    return m * x + b

# %%
popt,pcov = curve_fit(line, x, y)

# %%
plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

# %%
plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
yfit = line(xfit, *popt)

plt.plot(xfit, yfit)

# %%
plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
mfit, bfit = popt
yfit = line(xfit, mfit, bfit)

plt.plot(xfit, yfit)

# %%
def quad(x, a, b, c):
    return a * x**2 + b * x + c

popt,pcov = curve_fit(quad, x, y)

plt.scatter(x,y)

xfit = np.linspace(0.,10.,100)
afit, bfit, cfit =  popt
yfit = quad(xfit, afit, bfit, cfit)

plt.plot(xfit, yfit)

popt,pcov = curve_fit(line, x, y)

yfit = line(xfit, popt[0], popt[1])

plt.plot(xfit, yfit)

# %%
def quad(x, a, b, c):
    return a * x**2 + b * x + c

def toomuch(x, a, b, c, d, e, f):
    return a * x**5 + b * x**4 + c * x**3 + d * x**2 + e * x + f

def funfunc(x, a, b, c):
    return np.sin(a * np.sin(b * np.sin(c * np.sin(x))))

plt.scatter(x,y)
xfit = np.linspace(0.,10.,100)


popt,pcov = curve_fit(quad, x, y)
afit, bfit, cfit =  popt
yfit = quad(xfit, afit, bfit, cfit)
plt.plot(xfit, yfit,'g-')

popt,pcov = curve_fit(toomuch, x, y)
yfit = toomuch(xfit, *popt)
plt.plot(xfit, yfit,'r-')

popt,pcov = curve_fit(funfunc, x, y)
yfit = funfunc(xfit, popt[0], popt[1], popt[2])
plt.plot(xfit, yfit, 'y-')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_74340/3465563382.py in <module>
#      21 plt.plot(xfit, yfit,'r-')
#      22
# ---> 23 popt,pcov = curve_fit(funfunc, x, y)
#      24 yfit = funfunc(xfit, popt[0], popt[1], popt[2])
#      25 plt.plot(xfit, yfit, 'y-')
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     792         cost = np.sum(infodict['fvec'] ** 2)
#     793         if ier not in [1, 2, 3, 4]:
# --> 794             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     795     else:
#     796         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 800.

# %%
## So I really messed up and missunderstood the assignment and the fact that it was homework and for some reason thought it was an in class activity? I realized yesterday in class that it wasnt and then messed up when trying to make a branch and work on it then which was just foolish of me. I have been consistently a mess this entire semester so I am very sorry for that.
